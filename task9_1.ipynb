# %% [markdown]
# <a href="https://colab.research.google.com/github/vverfy/first_repository/blob/main/task9_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("/content/books.csv")
df23=df[df["Год"].isin([2023])]
df24=df[df["Год"].isin([2024])]

x1=df23["Месяц"]
y1=df23["Книги"]

x2=df24["Месяц"]
y2=df24["Страницы"]

def line_chart(x1, y1):
  plt.plot(x1, y1, marker="*", mfc="#4682B4", color="#FF1493")
  plt.grid(True)
  plt.xlabel("Месяцы")
  plt.ylabel("Количество книг")
  plt.title("Прочитанные книги за год")
  plt.legend("Прочитано книг за месяц")
  return plt.show()

def bar_chart(x2, y2):
  plt.bar(x2, y2, color="#98FB98")
  plt.grid(True)
  plt.xlabel("Месяцы")
  plt.ylabel("Количество страниц")
  plt.title("Прочитанные страницы за год")
  plt.legend("Прочитано страниц за месяц")
  return plt.show()

plt.subplot(2, 1, 1)
line_chart(x1, y1)
plt.subplot(2, 1, 2)
bar_chart(x2, y2)
